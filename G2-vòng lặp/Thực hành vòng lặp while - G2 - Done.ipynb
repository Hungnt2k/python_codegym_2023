# %%
'''
Khởi động 1: Viết chương trình in ra tất cả các số chia hết cho cả 5 và 7 trong khoảng từ 1500 đến 2700
'''
# Out:
# '\nKhởi động 1: Viết chương trình in ra tất cả các số chia hết cho cả 5 và 7 trong khoảng từ 1500 đến 2700\n'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
i = 1500

while i <= 2700 :
    if i % 5 == 0 and i % 7 == 0:
        print(i)
    i += 1
# Out:
# 1505
# 1540
# 1575
# 1610
# 1645
# 1680
# 1715
# 1750
# 1785
# 1820
# 1855
# 1890
# 1925
# 1960
# 1995
# 2030
# 2065
# 2100
# 2135
# 2170
# 2205
# 2240
# 2275
# 2310
# 2345
# 2380
# 2415
# 2450
# 2485
# 2520
# 2555
# 2590
# 2625
# 2660
# 2695

# %%
'''
Bài 2: Viết chương trình nhập vào chiều cao tam giác vuông và in ra tam giác có hình dạng như sau:
* * * * * *
* * * * *
* * * *
* * *
* *
*
'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
height = int(input("Nhập chiều cao tam giác vuông: "))
while height > 0:
    print("* " * height)
    height -= 1
# Out:
# Nhập chiều cao tam giác vuông: 6
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
'''
Bài 3: Viết chương trình nhập vào chiều cao tam giác vuông và in ra tam giác có hình dạng như sau:
* - * - *
* - * -
* - *
* -
*
'''
# Chưa làm :<

height = int(input("Nhập chiều cao tam giác vuông: "))
while height > 0:
    if height % 2 != 0:
        triangle = "* - " * height
        print(triangle.rstrip())
        print(triangle.rstrip('-'))
    height -= 1
# Out:
# Nhập chiều cao tam giác vuông: 5
# * - * - * - * - * -
# * - * - * - * - * -
# * - * - * -
# * - * - * -
# * -
# * -

# %%
'''
Bài 4: Viết chương trình nhập vào một số nguyên n và in ra các số từ 1 đến n với các trường hợp ngoại lệ như sau:
- Nếu số đó chia hết cho 3 thì in "py"
- Nếu số đó chia hết cho 7 thì in "thon"
- Nếu số đó chia hết cho cả 3 và 4 thì in "python"

Ví dụ: n = 25
1
2
py
4
5
py
thon
8
py
10
11
py
13
thon
py
16
17
py
19
20
python
22
23
py
25
'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input("Input n: "))
i = 1
while i <= n:
    if i % 3 == 0:
        print("py")
    elif i % 7 == 0:
        print("thon")
    elif i % 3 == 0 and i % 4 == 0:
        print("python")
    else:
        print(i)
    i += 1
# Out:
# Input n: 25
# 1
# 2
# py
# 4
# 5
# py
# thon
# 8
# py
# 10
# 11
# py
# 13
# thon
# py
# 16
# 17
# py
# 19
# 20
# py
# 22
# 23
# py
# 25

# %%
'''
Bài 5: Viết chương trình nhập vào một số và kiểm tra xem số đó có phải là số nguyên tố hay không
Note: Số nguyên tố là số chỉ chia hết cho 1 và chính nó
'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input("Please input n: "))
i = 2
if n < 2: print (f"{n} is not a prime number")
else:
    while i < n:
        if n % i == 0: print (f"{n} is not a prime number")
        break
        i += 1
        print(f"{n} is a prime number")
# Out:
# Please input n: 10
# 10 is not a prime number

# %%
'''
Bài 6: Viết chương trình mô phỏng trò chơi kéo búa bao theo luật chơi như sau:
Quy ước: 1 - búa, 2 - kéo, 3 - bao
Khi trò chơi bắt đầu, yêu cầu người chơi nhập 1 số từ bàn phím đại diện cho kéo, búa, bao
Chương trình tự random ra một lựa chọn từ 1 đến 3.
Nếu người chơi thua thì tiếp tục chơi cho đến khi thắng thì kết thúc chương trình.
Ví dụ:

Mời lựa chọn(1 - búa, 2 - kéo, 3 - bao): 1
Máy tính chọn: 3
Người chơi thua.

Mời lựa chọn(1 - búa, 2 - kéo, 3 - bao): 2
Máy tính chọn: 1
Người chơi thua.

Mời lựa chọn(1 - búa, 2 - kéo, 3 - bao): 1
Máy tính chọn: 2
Người chơi thắng.
'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random

while True:
    print("Mời lựa chọn (1 - búa, 2 - kéo, 3 - bao):")
    player_choice = int(input())
    computer_choice = random.randint(1, 3)

    if player_choice == 1:  # Người chơi chọn búa
        if computer_choice == 1:
            print("Máy tính chọn: búa")
            print("Hòa!")
        elif computer_choice == 2:
            print("Máy tính chọn: kéo")
            print("Người chơi thắng!")
            break
        else:
            print("Máy tính chọn: bao")
            print("Người chơi thua.")

    elif player_choice == 2:  # Người chơi chọn kéo
        if computer_choice == 1:
            print("Máy tính chọn: búa")
            print("Người chơi thua.")
        elif computer_choice == 2:
            print("Máy tính chọn: kéo")
            print("Hòa!")
        else:
            print("Máy tính chọn: bao")
            print("Người chơi thắng!")
            break

    elif player_choice == 3:  # Người chơi chọn bao
        if computer_choice == 1:
            print("Máy tính chọn: búa")
            print("Người chơi thắng!")
            break
        elif computer_choice == 2:
            print("Máy tính chọn: kéo")
            print("Người chơi thua.")
        else:
            print("Máy tính chọn: bao")
            print("Hòa!")

    else:
        print("Lựa chọn không hợp lệ. Mời chọn lại.")
# Out:
# Mời lựa chọn (1 - búa, 2 - kéo, 3 - bao):
# 1
# Máy tính chọn: bao
# Người chơi thua.
# Mời lựa chọn (1 - búa, 2 - kéo, 3 - bao):
# 1
# Máy tính chọn: kéo
# Người chơi thắng!
